# %%
import numpy as np
import pandas as pd

import tensorflow as tf

import re
import os
import cv2 as cv
# Out:
# 2023-02-27 15:28:12.157311: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/oracle/instantclient_19_9:
# 2023-02-27 15:28:12.157329: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# #### Importa dados

# %%
BATCH_SIZE = 32

# Entrada da rede e tamanho das imagens
input_shape = (160, 160, 3)

# %%
def structure_images(path_to_subset):
    
    # Listas pra salvar as imagens e rotulos
    X = []
    Y = []

    # Itera sobre as classes no diretorio
    for folder in os.listdir(path_to_subset):

        # Le as imagens da classe e carrega em X e Y
        for image in os.listdir(os.path.join(path_to_subset, folder)):
            path_to_image = os.path.join(path_to_subset, folder, image)
            image = cv.imread(path_to_image)    
            image = cv.resize(image, (input_shape[0], input_shape[1]))
            label = [folder]
            if '_' in folder:
                label = folder.split('_')

            X.append(image)
            Y.append(label)

    X = np.array(X)
    Y = np.array(Y)
    
    return(X, Y)

# %%
x_train, y_train = structure_images('./rostos/train')
# Out:
# /tmp/ipykernel_224123/4285378919.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Y = np.array(Y)

# %%
x_val, y_val = structure_images('./rostos/validation')
# Out:
# /tmp/ipykernel_224123/4285378919.py:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   Y = np.array(Y)

# %% [markdown]
# #### Formata rotulos pra classificacal multilabel

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer()
y_train = mlb.fit_transform(y_train)
y_val = mlb.transform(y_val)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.1, stratify = y_train, shuffle = True, random_state=3)

# %%
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (1755, 160, 160, 3) (1755, 2)
# (642, 160, 160, 3) (642, 2)

# %% [markdown]
# #### Formata dados

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
# Out:
# 2023-02-27 15:28:28.924157: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/dshome/venv/lib/python3.8/site-packages/cv2/../../lib64:/opt/oracle/instantclient_19_9:
# 2023-02-27 15:28:28.924182: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-02-27 15:28:28.924197: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ec2-sa1-1b-p-analetslytics-dev): /proc/driver/nvidia/version does not exist
# 2023-02-27 15:28:28.924451: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_dataset = train_dataset.batch(BATCH_SIZE).repeat().prefetch(1)
val_dataset = val_dataset.batch(BATCH_SIZE).repeat().prefetch(1)

# %% [markdown]
# #### Modela rede

# %%
from tensorflow.keras import layers

resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(input_shape[0], input_shape[1]),
    layers.Rescaling(1./255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.1)
])

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D
from keras.layers import BatchNormalization, Activation, Dropout

model = Sequential()

model.add(resize_and_rescale)
model.add(data_augmentation)

model.add(Conv2D(16, 3, padding = 'same', input_shape = input_shape, kernel_initializer = 'he_normal', activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(3))
model.add(Dropout(0.25))

# model.add(Conv2D(32, 3, padding = 'same', input_shape = input_shape, kernel_initializer = 'he_normal', activation = 'relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(3))
# model.add(Dropout(0.25))

# model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
# model.add(BatchNormalization())
# model.add(Conv2D(64, 3, padding = 'same', kernel_initializer = 'he_normal', activation = 'relu'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D())
# model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(32, activation = 'relu', kernel_initializer = 'he_normal'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(len(mlb.classes_), activation = 'sigmoid'))

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# Checkpoint pra salvar o melhor modelo
checkpoint = ModelCheckpoint('../working/best_model.hdf5', save_best_only = True, monitor = 'val_loss')
early_stopping = EarlyStopping(patience=15, restore_best_weights=True)

optimizer = Adam() 
model.compile(optimizer=optimizer , loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_dataset,
    steps_per_epoch=len(x_train) // BATCH_SIZE,
    
    validation_data = val_dataset,
    validation_steps=len(x_val) // BATCH_SIZE,
    
    epochs = 80, 
    callbacks = [checkpoint, early_stopping],
)
# Out:
# Epoch 1/80
# 54/54 [==============================] - 11s 187ms/step - loss: 0.7482 - accuracy: 0.5851 - val_loss: 0.9503 - val_accuracy: 0.2875
# Epoch 2/80
# 54/54 [==============================] - 10s 181ms/step - loss: 0.2634 - accuracy: 0.6494 - val_loss: 0.3389 - val_accuracy: 0.6328
# Epoch 24/80
# 54/54 [==============================] - 10s 181ms/step - loss: 0.2454 - accuracy: 0.6553 - val_loss: 0.4372 - val_accuracy: 0.5875
# Epoch 25/80
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2509 - accuracy: 0.6611 - val_loss: 0.5569 - val_accuracy: 0.7609
# Epoch 26/80
# 54/54 [==============================] - 10s 181ms/step - loss: 0.2508 - accuracy: 0.6802 - val_loss: 0.5058 - val_accuracy: 0.7734
# Epoch 27/80
# 54/54 [==============================] - 10s 181ms/step - loss: 0.2437 - accuracy: 0.6849 - val_loss: 0.8310 - val_accuracy: 0.6812
# Epoch 28/80
# 54/54 [==============================] - 10s 183ms/step - loss: 0.2333 - accuracy: 0.6738 - val_loss: 0.5935 - val_accuracy: 0.8031
# Epoch 29/80
# 54/54 [==============================] - 10s 181ms/step - loss: 0.2358 - accuracy: 0.6912 - val_loss: 0.4940 - val_accuracy: 0.6172
# Epoch 30/80
# 54/54 [==============================] - 10s 181ms/step - loss: 0.2395 - accuracy: 0.6883 - val_loss: 1.4432 - val_accuracy: 0.5813
# Epoch 31/80
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2358 - accuracy: 0.6785 - val_loss: 0.5301 - val_accuracy: 0.8266
# Epoch 32/80
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2325 - accuracy: 0.6901 - val_loss: 0.6580 - val_accuracy: 0.6484
# Epoch 33/80
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2333 - accuracy: 0.6936 - val_loss: 0.8010 - val_accuracy: 0.6078
# Epoch 34/80
# 54/54 [==============================] - 10s 183ms/step - loss: 0.2268 - accuracy: 0.6959 - val_loss: 0.9700 - val_accuracy: 0.6125
# Epoch 35/80
# 54/54 [==============================] - 10s 182ms/step - loss: 0.2304 - accuracy: 0.6970 - val_loss: 0.9648 - val_accuracy: 0.5969
# Epoch 36/80
# 54/54 [==============================] - 10s 183ms/step - loss: 0.2246 - accuracy: 0.6965 - val_loss: 0.7117 - val_accuracy: 0.7047
# Epoch 37/80
# 54/54 [==============================] - 10s 183ms/step - loss: 0.2245 - accuracy: 0.6825 - val_loss: 1.0831 - val_accuracy: 0.5500

# %% [markdown]
# #### Plota dados do treino

# %%
# Plot os resultados do treino
pd.DataFrame(history.history).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Carrega melhor modelo

# %%
# Load do melhor modelo
model.load_weights('../working/best_model.hdf5')

# Salva o modelo par ausar depois
model.save('../working/model.hdf5')

# %% [markdown]
# #### Avalia modelo no teste

# %%
from sklearn.metrics import multilabel_confusion_matrix

# Classifica observacoes de teste
def predict_labels(model, x_test):
    preds = model.predict(x_test)
    preds = np.where(preds < 0.5, 0, 1)
    return(preds)

preds = predict_labels(model, x_test)

# Cria matriz de confusao
confusion = multilabel_confusion_matrix(y_test, preds)
confusion
# Out:
# array([[[ 43,  14],
#         [  2, 137]],
#
#        [[  3,  16],
#         [  6, 171]]])

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(y_test, preds, average='micro')
# Out:
# (0.9112426035502958, 0.9746835443037974, 0.9418960244648318, None)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, preds)
# Out:
# 0.8112244897959183

# %% [markdown]
# #### Mostra imagens com classe real e prevista

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(x_test[i])
    plt.title('real: ' + str(y_test[i])+ " - pred: "+ str(preds[i]))
    plt.axis("off")
plt.show()
